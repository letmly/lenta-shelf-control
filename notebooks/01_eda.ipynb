# %% [markdown]
# # EDA — Lenta Shelf Control
#
# Цель: понять распределение размеров bbox, частоту повторов одного ценника, читаемость QR, шаблоны ценников.
#
# TODO Д1:
# - [ ] Загрузить три CSV из data/labeled
# - [ ] Извлечь кадры из видео по frame_timestamp
# - [ ] Вырезать кропы по bbox
# - [ ] Группировать кропы визуально по шаблонам (3 примера на каждый)
# - [ ] Распределение size, fps, resolution

# %%
import pandas as pd
from pathlib import Path

DATA = Path('../data/labeled')
csvs = list(DATA.glob('*/*.csv'))
df = pd.concat([pd.read_csv(c) for c in csvs], ignore_index=True)
print(df.shape)
df.head()
